# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
from scipy import stats
# %matplotlib inline
plt.style.use('seaborn-dark')

# %%
beer_totals = pd.read_csv(
    '../data/../data/minor_beers.csv', 
    delimiter=","
)
beer_totals['name'] = beer_totals['Line Item']
beer_totals.set_index('name', inplace=True)
beer_totals.drop("Unnamed: 0", axis = 1, inplace=True)
print(beer_totals.shape)
beer_totals.head(1)
# Out:
# (40, 11)
#                                Line Item    Cost   Price  Quantity  Modifiers  \
# name
# Mississipecan Brown  Mississipecan Brown  170.85  1530.0     399.0      49.25
#
#                      Subtotal  Discounts  Net Total  Tax  Total Due  \
# name
# Mississipecan Brown   2443.25     106.66    2336.59  0.0    2336.59
#
#                      Customer ID
# name
# Mississipecan Brown   3752722093

# %%
beer_sales = pd.read_csv(
    '../data/../data/minor_beer_sales.csv', 
    delimiter=","
)
beer_sales.set_index("Time", inplace=True)
beer_sales["Time"] = beer_sales["Time2"]

beer_sales["datetime"] = pd.to_datetime(beer_sales["Time"])
beer_sales["datetime_hour"] = pd.DatetimeIndex(beer_sales['Time']).round("h")
beer_sales['year'] = pd.DatetimeIndex(beer_sales['datetime']).to_period("Y")
cols_to_drop = ["Time.1", "Time2", ]

beer_sales['name'] = beer_sales['Line Item'] + " " + beer_sales['year'].astype('str')
beer_sales.drop(cols_to_drop, inplace=True, axis=1)
print(beer_sales.shape)
beer_sales.head(1)
# Out:
# (4405, 18)
#                                Line Item  Cost  Price  Quantity  Modifiers  \
# Time
# 2020-01-01 00:54:00  Mississipecan Brown  0.67    6.0       5.0        0.0
#
#                      Subtotal  Discounts  Net Total  Tax  Total Due  \
# Time
# 2020-01-01 00:54:00      30.0        0.0       30.0  0.0       30.0
#
#                                            Transaction ID  Customer ID  \
# Time
# 2020-01-01 00:54:00  C806F59B-13E5-4551-8AA8-AAE11F0914DC     13685111
#
#                                time_hour                 Time  \
# Time
# 2020-01-01 00:54:00  2020-01-01 01:00:00  2020-01-01 00:54:00
#
#                                datetime       datetime_hour  year  \
# Time
# 2020-01-01 00:54:00 2020-01-01 00:54:00 2020-01-01 01:00:00  2020
#
#                                          name
# Time
# 2020-01-01 00:54:00  Mississipecan Brown 2020

# %%
beer_sales["name"].unique()
# Out:
# array(['Mississipecan Brown 2020', 'Mississipecan Brown 2019',
#        'Pistachio 2019', 'Pistachio 2020', 'Festivus Ale 2020',
#        'Festivus Ale 2019', 'SiPA 2019', 'SiPA 2020',
#        'Ozarktoberfest 2019', 'Ozarktoberfest 2020',
#        'Cucumber Dill Gose 2019', 'Sunny Time IPA 2019', 'Drew Brew 2019',
#        'Esteemed Punk 2019', 'Esteemed Punk 2020',
#        'Landlocked IPA Special 2019', 'Zombie Scottish Ale 2019',
#        "Valentine's Date Night Stout 2019",
#        "Valentine's Date Night Stout 2020", 'Resilience IPA 2019',
#        'Rock Picker Grisette 2019', 'Ayerish Stout 2019',
#        'Ayerish Stout 2020', 'Hoprechaun Red 2019', 'Hoprechaun Red 2020',
#        'Star Spangled Ale 2019', 'ReBar A Grunge IPA 2020', 'Shandy 2019',
#        'Shandy 2020', 'Weisse Old Ozarker flavored 2019',
#        'This Little Lite of Mine Ale 2019', '36° 30’ Kolsch 2020',
#        'WBCo A Real American Lager 2020', 'Honey Orange Wheat 2020',
#        'Zombilly Deluxe Scotch Ale 2020',
#        'Zombilly Deluxe Scotch Ale 2019', 'Belgian Pale Ale 2019',
#        'Belgian Pale Ale 2020', 'Cashmere IPA 2020',
#        'Russian Imp Stout 2019', 'Russian Imp Stout 2020',
#        'Mouths of Decadence Toast Ale 2020',
#        "Glass Whoopin' Barleywine 2019", 'Landbridge DIPA 2020',
#        'Black is Beautiful Stout 2020', 'Java Porter 2020',
#        'Mississipecan De-LUX 2019', 'Golden Ale 2019',
#        'Pit Boss Ale 2020', 'OSB 2019', 'Mark of the Beast Quad 2019',
#        'Belgian Trippel 2020'], dtype=object)

# %% [markdown]
# ## Let's start by graphing the minor beers, each on its own chart

# %%
fig, ax = plt.subplots(len(beer_sales["name"].unique()),1, figsize=(20,4*len(beer_totals.index)))
i= 0
for beer in beer_sales["name"].unique():
    this_beer = beer_sales[beer_sales["name"] == beer]
    sales_by_hour = this_beer.groupby(this_beer["datetime_hour"].dt.date).sum()
    
    this_beer.head(2)
    ax[i].plot("Quantity", data=sales_by_hour, linewidth=2, alpha=1, label=beer)

    ax[i].set_title(f"Number of { beer } sold.")
    ax[i].set_ylabel("Number of Sales")
    ax[i].legend()

    i += 1

# %%
beer_sales
# Out:
#                                Line Item  Cost  Price  Quantity  Modifiers  \
# Time
# 2020-01-01 00:54:00  Mississipecan Brown  0.67    6.0       5.0       0.00
# 2020-01-01 00:18:00  Mississipecan Brown  0.67    6.0       1.0       0.00
# 2020-01-01 00:16:00  Mississipecan Brown  0.67    6.0       1.0       0.00
# 2019-12-31 22:53:00  Mississipecan Brown  0.67    6.0       1.0       0.00
# 2019-12-31 22:53:00  Mississipecan Brown  0.67    6.0       1.0       0.00
# ...                                  ...   ...    ...       ...        ...
# 2020-08-28 18:55:00      Belgian Trippel  0.77    6.5       2.0       0.00
# 2020-08-28 17:13:00      Belgian Trippel  0.77    6.5       1.0      22.75
# 2020-08-28 17:00:00      Belgian Trippel  0.77    6.5       1.0       6.50
# 2020-08-27 20:51:00      Belgian Trippel  0.77    6.5       1.0       0.00
# 2020-08-27 19:36:00      Belgian Trippel  0.77    6.5       1.0       0.00
#
#                      Subtotal  Discounts  Net Total  Tax  Total Due  \
# Time
# 2020-01-01 00:54:00     30.00        0.0      30.00  0.0      30.00
# 2020-01-01 00:18:00      6.00        0.0       6.00  0.0       6.00
# 2020-01-01 00:16:00      6.00        3.0       3.00  0.0       3.00
# 2019-12-31 22:53:00      6.00        0.0       6.00  0.0       6.00
# 2019-12-31 22:53:00      6.00        0.0       6.00  0.0       6.00
# ...                       ...        ...        ...  ...        ...
# 2020-08-28 18:55:00     13.00        0.0      13.00  0.0      13.00
# 2020-08-28 17:13:00     29.25        0.0      29.25  0.0      29.25
# 2020-08-28 17:00:00     13.00        0.0      13.00  0.0      13.00
# 2020-08-27 20:51:00      6.50        0.0       6.50  0.0       6.50
# 2020-08-27 19:36:00      6.50        0.0       6.50  0.0       6.50
#
#                                            Transaction ID  Customer ID  \
# Time
# 2020-01-01 00:54:00  C806F59B-13E5-4551-8AA8-AAE11F0914DC     13685111
# 2020-01-01 00:18:00  40992540-7C50-46C9-89B2-90CB0E1C630A     13685111
# 2020-01-01 00:16:00  C9EC9193-D293-4CA4-9C16-5025FC750817     13685111
# 2019-12-31 22:53:00  D4EC837E-9CD8-4115-8581-FA3B424A87A7     13685111
# 2019-12-31 22:53:00  D4EC837E-9CD8-4115-8581-FA3B424A87A7     13685111
# ...                                                   ...          ...
# 2020-08-28 18:55:00  0D71B1F8-9DFF-4800-977E-16FD90B6788C     13685111
# 2020-08-28 17:13:00  5FBF6030-F9B9-4D94-8B4A-52F101F60492     42660475
# 2020-08-28 17:00:00  B13B7B5C-A6CC-4BC2-A397-AAF325D30E48     13685111
# 2020-08-27 20:51:00  DADE973D-66C8-41FA-99EF-67FD01519F58     13685111
# 2020-08-27 19:36:00  4479809E-99CB-4457-9457-E30E12309BC2     13685111
#
#                                time_hour                 Time  \
# Time
# 2020-01-01 00:54:00  2020-01-01 01:00:00  2020-01-01 00:54:00
# 2020-01-01 00:18:00  2020-01-01 00:00:00  2020-01-01 00:18:00
# 2020-01-01 00:16:00  2020-01-01 00:00:00  2020-01-01 00:16:00
# 2019-12-31 22:53:00  2019-12-31 23:00:00  2019-12-31 22:53:00
# 2019-12-31 22:53:00  2019-12-31 23:00:00  2019-12-31 22:53:00
# ...                                  ...                  ...
# 2020-08-28 18:55:00  2020-08-28 19:00:00  2020-08-28 18:55:00
# 2020-08-28 17:13:00  2020-08-28 17:00:00  2020-08-28 17:13:00
# 2020-08-28 17:00:00  2020-08-28 17:00:00  2020-08-28 17:00:00
# 2020-08-27 20:51:00  2020-08-27 21:00:00  2020-08-27 20:51:00
# 2020-08-27 19:36:00  2020-08-27 20:00:00  2020-08-27 19:36:00
#
#                                datetime       datetime_hour  year  \
# Time
# 2020-01-01 00:54:00 2020-01-01 00:54:00 2020-01-01 01:00:00  2020
# 2020-01-01 00:18:00 2020-01-01 00:18:00 2020-01-01 00:00:00  2020
# 2020-01-01 00:16:00 2020-01-01 00:16:00 2020-01-01 00:00:00  2020
# 2019-12-31 22:53:00 2019-12-31 22:53:00 2019-12-31 23:00:00  2019
# 2019-12-31 22:53:00 2019-12-31 22:53:00 2019-12-31 23:00:00  2019
# ...                                 ...                 ...   ...
# 2020-08-28 18:55:00 2020-08-28 18:55:00 2020-08-28 19:00:00  2020
# 2020-08-28 17:13:00 2020-08-28 17:13:00 2020-08-28 17:00:00  2020
# 2020-08-28 17:00:00 2020-08-28 17:00:00 2020-08-28 17:00:00  2020
# 2020-08-27 20:51:00 2020-08-27 20:51:00 2020-08-27 21:00:00  2020
# 2020-08-27 19:36:00 2020-08-27 19:36:00 2020-08-27 20:00:00  2020
#
#                                          name
# Time
# 2020-01-01 00:54:00  Mississipecan Brown 2020
# 2020-01-01 00:18:00  Mississipecan Brown 2020
# 2020-01-01 00:16:00  Mississipecan Brown 2020
# 2019-12-31 22:53:00  Mississipecan Brown 2019
# 2019-12-31 22:53:00  Mississipecan Brown 2019
# ...                                       ...
# 2020-08-28 18:55:00      Belgian Trippel 2020
# 2020-08-28 17:13:00      Belgian Trippel 2020
# 2020-08-28 17:00:00      Belgian Trippel 2020
# 2020-08-27 20:51:00      Belgian Trippel 2020
# 2020-08-27 19:36:00      Belgian Trippel 2020
#
# [4405 rows x 18 columns]

# %% [markdown]
# # At this stage, we pull out a single beer and start looking at things that might indicate a strength or weakness

# %%
this_beer = beer_sales[beer_sales['Line Item'] == "Mississipecan Brown" ].copy()
print(this_beer.shape)
this_beer.head(3)
# Out:
# (255, 18)
#                                Line Item  Cost  Price  Quantity  Modifiers  \
# Time
# 2020-01-01 00:54:00  Mississipecan Brown  0.67    6.0       5.0        0.0
# 2020-01-01 00:18:00  Mississipecan Brown  0.67    6.0       1.0        0.0
# 2020-01-01 00:16:00  Mississipecan Brown  0.67    6.0       1.0        0.0
#
#                      Subtotal  Discounts  Net Total  Tax  Total Due  \
# Time
# 2020-01-01 00:54:00      30.0        0.0       30.0  0.0       30.0
# 2020-01-01 00:18:00       6.0        0.0        6.0  0.0        6.0
# 2020-01-01 00:16:00       6.0        3.0        3.0  0.0        3.0
#
#                                            Transaction ID  Customer ID  \
# Time
# 2020-01-01 00:54:00  C806F59B-13E5-4551-8AA8-AAE11F0914DC     13685111
# 2020-01-01 00:18:00  40992540-7C50-46C9-89B2-90CB0E1C630A     13685111
# 2020-01-01 00:16:00  C9EC9193-D293-4CA4-9C16-5025FC750817     13685111
#
#                                time_hour                 Time  \
# Time
# 2020-01-01 00:54:00  2020-01-01 01:00:00  2020-01-01 00:54:00
# 2020-01-01 00:18:00  2020-01-01 00:00:00  2020-01-01 00:18:00
# 2020-01-01 00:16:00  2020-01-01 00:00:00  2020-01-01 00:16:00
#
#                                datetime       datetime_hour  year  \
# Time
# 2020-01-01 00:54:00 2020-01-01 00:54:00 2020-01-01 01:00:00  2020
# 2020-01-01 00:18:00 2020-01-01 00:18:00 2020-01-01 00:00:00  2020
# 2020-01-01 00:16:00 2020-01-01 00:16:00 2020-01-01 00:00:00  2020
#
#                                          name
# Time
# 2020-01-01 00:54:00  Mississipecan Brown 2020
# 2020-01-01 00:18:00  Mississipecan Brown 2020
# 2020-01-01 00:16:00  Mississipecan Brown 2020

# %%
this_beer.hist(figsize=(20,10));

# %%
this_beer.drop("Customer ID", axis=1).boxplot(figsize=(20,5));

# %% [markdown]
# ## At this point, I think we can look at quantity sold as an exponential distribution

# %%
this_beer['Quantity'].hist(bins = 90)
# Out:
# <AxesSubplot:>

# %%
beer_sales['Quantity'].hist(bins = 90)
# Out:
# <AxesSubplot:>

# %%
this_beer.head()
# Out:
#                                Line Item  Cost  Price  Quantity  Modifiers  \
# Time
# 2020-01-01 00:54:00  Mississipecan Brown  0.67    6.0       5.0        0.0
# 2020-01-01 00:18:00  Mississipecan Brown  0.67    6.0       1.0        0.0
# 2020-01-01 00:16:00  Mississipecan Brown  0.67    6.0       1.0        0.0
# 2019-12-31 22:53:00  Mississipecan Brown  0.67    6.0       1.0        0.0
# 2019-12-31 22:53:00  Mississipecan Brown  0.67    6.0       1.0        0.0
#
#                      Subtotal  Discounts  Net Total  Tax  Total Due  \
# Time
# 2020-01-01 00:54:00      30.0        0.0       30.0  0.0       30.0
# 2020-01-01 00:18:00       6.0        0.0        6.0  0.0        6.0
# 2020-01-01 00:16:00       6.0        3.0        3.0  0.0        3.0
# 2019-12-31 22:53:00       6.0        0.0        6.0  0.0        6.0
# 2019-12-31 22:53:00       6.0        0.0        6.0  0.0        6.0
#
#                                            Transaction ID  Customer ID  \
# Time
# 2020-01-01 00:54:00  C806F59B-13E5-4551-8AA8-AAE11F0914DC     13685111
# 2020-01-01 00:18:00  40992540-7C50-46C9-89B2-90CB0E1C630A     13685111
# 2020-01-01 00:16:00  C9EC9193-D293-4CA4-9C16-5025FC750817     13685111
# 2019-12-31 22:53:00  D4EC837E-9CD8-4115-8581-FA3B424A87A7     13685111
# 2019-12-31 22:53:00  D4EC837E-9CD8-4115-8581-FA3B424A87A7     13685111
#
#                                time_hour                 Time  \
# Time
# 2020-01-01 00:54:00  2020-01-01 01:00:00  2020-01-01 00:54:00
# 2020-01-01 00:18:00  2020-01-01 00:00:00  2020-01-01 00:18:00
# 2020-01-01 00:16:00  2020-01-01 00:00:00  2020-01-01 00:16:00
# 2019-12-31 22:53:00  2019-12-31 23:00:00  2019-12-31 22:53:00
# 2019-12-31 22:53:00  2019-12-31 23:00:00  2019-12-31 22:53:00
#
#                                datetime       datetime_hour  year  \
# Time
# 2020-01-01 00:54:00 2020-01-01 00:54:00 2020-01-01 01:00:00  2020
# 2020-01-01 00:18:00 2020-01-01 00:18:00 2020-01-01 00:00:00  2020
# 2020-01-01 00:16:00 2020-01-01 00:16:00 2020-01-01 00:00:00  2020
# 2019-12-31 22:53:00 2019-12-31 22:53:00 2019-12-31 23:00:00  2019
# 2019-12-31 22:53:00 2019-12-31 22:53:00 2019-12-31 23:00:00  2019
#
#                                          name
# Time
# 2020-01-01 00:54:00  Mississipecan Brown 2020
# 2020-01-01 00:18:00  Mississipecan Brown 2020
# 2020-01-01 00:16:00  Mississipecan Brown 2020
# 2019-12-31 22:53:00  Mississipecan Brown 2019
# 2019-12-31 22:53:00  Mississipecan Brown 2019

# %% [markdown]
# ## Create an ordinal column from datetime so we can do a regression

# %%
this_beer['hour_ordinal'] = this_beer['datetime_hour'].apply(lambda x: x.toordinal())
this_beer.head(1)
# Out:
#                                Line Item  Cost  Price  Quantity  Modifiers  \
# Time
# 2020-01-01 00:54:00  Mississipecan Brown  0.67    6.0       5.0        0.0
#
#                      Subtotal  Discounts  Net Total  Tax  Total Due  \
# Time
# 2020-01-01 00:54:00      30.0        0.0       30.0  0.0       30.0
#
#                                            Transaction ID  Customer ID  \
# Time
# 2020-01-01 00:54:00  C806F59B-13E5-4551-8AA8-AAE11F0914DC     13685111
#
#                                time_hour                 Time  \
# Time
# 2020-01-01 00:54:00  2020-01-01 01:00:00  2020-01-01 00:54:00
#
#                                datetime       datetime_hour  year  \
# Time
# 2020-01-01 00:54:00 2020-01-01 00:54:00 2020-01-01 01:00:00  2020
#
#                                          name  hour_ordinal
# Time
# 2020-01-01 00:54:00  Mississipecan Brown 2020        737425

# %% [markdown]
# ## Let's overlay regression for all the beers and see what it looks like

# %%
import datetime

fig, ax = plt.subplots(1,1, figsize=(20,4))

this_beer = this_beer.sort_values('hour_ordinal')
this_beer['hour_ordinal'] = this_beer['datetime_hour'].apply(lambda x: x.toordinal())
sales_by_hour = this_beer.groupby(this_beer["datetime_hour"].dt.date).sum()

m, b = np.polyfit(this_beer['hour_ordinal'],this_beer['Quantity'],1)

ax.plot(this_beer['hour_ordinal'], this_beer['Quantity'])
ax.plot(this_beer['hour_ordinal'], m*this_beer['hour_ordinal'] + b, linewidth=3, color="red")

# %% [markdown]
# ## Get a simple plot to see how the beers overlap

# %%
fig, ax = plt.subplots(1, figsize=(20,5))

for beer in beer_sales["name"].unique():

    this_beer = beer_sales[beer_sales["name"] == beer].copy()
    
    this_beer['hour_ordinal'] = this_beer['datetime_hour'].apply(lambda x: x.toordinal())
    minimum_ord = this_beer['hour_ordinal'].min()
    this_beer['hour_ordinal_normalized'] = this_beer['hour_ordinal']  - minimum_ord
    sales_by_hour = this_beer.groupby(this_beer["datetime_hour"].dt.date).sum()
    ax.plot("Quantity", data=sales_by_hour, linewidth=2, alpha=1, label=beer)

ax.set_title(f"Trends in Beer sales")
ax.set_ylabel("Number of Sales")
# Out:
# Text(0, 0.5, 'Number of Sales')

# %% [markdown]
# ## Romove the beers that were off tap for long periods, as the slope will be wrong for a regression line

# %%
fig, ax = plt.subplots(1, figsize=(20,5))

for beer in beer_sales["name"].unique():

    this_beer = beer_sales[beer_sales["name"] == beer].copy()
    
    this_beer['hour_ordinal'] = this_beer['datetime_hour'].apply(lambda x: x.toordinal())
    minimum_ord = this_beer['hour_ordinal'].min()
    this_beer['hour_ordinal_normalized'] = this_beer['hour_ordinal']  - minimum_ord
    if this_beer['hour_ordinal_normalized'].max() < 150:
        sales_by_hour = this_beer.groupby(this_beer["datetime_hour"].dt.date).sum()
        ax.plot("Quantity", data=sales_by_hour, linewidth=2, alpha=1, label=beer)

ax.set_title(f"Trends in Beer sales")
ax.set_ylabel("Number of Sales")
# Out:
# Text(0, 0.5, 'Number of Sales')

# %% [markdown]
# ## Build a linear regression line for each beer, and normalize the times, and y intercept so that they all start at the same place

# %%
fig, ax = plt.subplots(1, figsize=(20,4))
# Save the slopes for a later cell
slopes=[]

for beer in beer_sales["name"].unique():
    
    this_beer = beer_sales[beer_sales["name"] == beer].copy()
    
    this_beer['hour_ordinal'] = this_beer['datetime_hour'].apply(lambda x: x.toordinal())
    minimum_ord = this_beer['hour_ordinal'].min()
    this_beer['hour_ordinal_normalized'] = this_beer['hour_ordinal']  - minimum_ord
    sales_by_hour = this_beer.groupby(this_beer["datetime_hour"].dt.date).sum()

    if this_beer['hour_ordinal_normalized'].max() < 150:
        m, b = np.polyfit(this_beer['hour_ordinal_normalized'],this_beer['Quantity'],1)
        slopes.append(m)
        # Normally we would leave a "+b" in the next part, but in this case we are only interested in the slopes.
        ax.plot(this_beer['hour_ordinal_normalized'], m*this_beer['hour_ordinal_normalized'])
    
    sales_by_hour = this_beer.groupby(this_beer["datetime_hour"].dt.date).sum()

ax.set_title(f"Regression slopes for each specialty beer")
ax.set_ylabel("Slope of Regression")
# Out:
# Text(0, 0.5, 'Slope of Regression')

# %% [markdown]
# ### If we take a minute and look at the values sorted, we see that it seems to form a symetrical distribution.

# %%
slopes.sort()
x_vals = np.arange(0, len(slopes))

fig, ax = plt.subplots(1,1, figsize=(20,4))
ax.set_title(f"Distribution of regression slopes for specialty beers")
ax.set_ylabel("Slope of Regression")

ax.plot(x_vals, slopes, linewidth=2, alpha=1, label=beer)

# %% [markdown]
# ## Let's look at the distance from the median for each slope

# %%
slopes = np.array(slopes)
slope_distances = []
slopes_mean = slopes.mean()
print(f"Slopes mean is {slopes_mean}")
for slope in slopes:
    distance_to_mean = abs(slope-slopes_mean)
    slope_distances.append(distance_to_mean)

x_vals = np.arange(0, len(slopes))

fig, ax = plt.subplots(1,1, figsize=(20,4))
ax.set_title(f"Distribution of regression slopes for specialty beers")
ax.set_ylabel("Slope of Regression")

ax.plot(x_vals, slope_distances, linewidth=2, alpha=1, label=beer)
# Out:
# Slopes mean is -0.004332109589837744

# %% [markdown]
# ### Creating a histogram indicates something close to a normal distribution

# %%
slopes = np.array(slopes)
slopes_std = slopes.std()
slopes_mean = slopes.mean()

fig, ax = plt.subplots(4,1, figsize=(20,6))

slopes_dist = stats.norm(loc=slopes_mean, scale=slopes_std)
support = np.linspace(-0.04, .03, 100)

x_vals = np.arange(0, len(slopes))
ax[0].hist(slopes, linewidth=2, alpha=1, label=beer, bins=9)
ax[1].plot(support, slopes_dist.pdf(support))

ax[2].hist(slopes, linewidth=2, alpha=1, label=beer, bins=9)
ax[2].plot(support, slopes_dist.pdf(support))

ax[3].hist(slopes, linewidth=2, alpha=1, label=beer, bins=50)
ax[3].plot(support, slopes_dist.pdf(support)/9)


print(f" There are { len(slopes) } beers being studied here.")
# Out:
#  There are 45 beers being studied here.

# %% [markdown]
# ### At this point, we've narrowed the field to only 45 data points. Resample?
